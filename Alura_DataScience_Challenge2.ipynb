# %% [markdown]
# <a href="https://colab.research.google.com/github/Angel-Arroyo-H/alura-data-science-challenge-2/blob/main/Alura_DataScience_Challenge2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracão

# %% [markdown]
# O formato do arquivo que precisamos ler é json. Usaremos a função read_json() da livraria pandas para ler o arquivo.

# %%
import pandas as pd

#url = 'https://raw.githubusercontent.com/alura-cursos/challenge2-data-science/refs/heads/main/TelecomX_Data.json'
url = 'https://raw.githubusercontent.com/Angel-Arroyo-H/alura-data-science-challenge-2/refs/heads/main/TelecomX_Data.json'
dados = pd.read_json(url)
dados
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 0        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1       {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                                 ...
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 0     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4     {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...                                                 ...
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account
# 0     {'Contract': 'One year', 'PaperlessBilling': '...
# 1     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4     {'Contract': 'Month-to-month', 'PaperlessBilli...
# ...                                                 ...
# 7262  {'Contract': 'One year', 'PaperlessBilling': '...
# 7263  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7264  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7265  {'Contract': 'Two year', 'PaperlessBilling': '...
# 7266  {'Contract': 'Two year', 'PaperlessBilling': '...
#
# [7267 rows x 6 columns]

# %% [markdown]
# Após ler o arquivo observamos que temos informações aninhadas nos campos customer, phone, internet e account, normalizaremos os dados usando a função pandas.json_normalize()

# %%
pd.json_normalize(dados['customer'])
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
pd.json_normalize(dados['phone'])
# Out:
#      PhoneService     MultipleLines
# 0             Yes                No
# 1             Yes               Yes
# 2             Yes                No
# 3             Yes                No
# 4             Yes                No
# ...           ...               ...
# 7262          Yes                No
# 7263          Yes               Yes
# 7264          Yes                No
# 7265          Yes                No
# 7266           No  No phone service
#
# [7267 rows x 2 columns]

# %%
pd.json_normalize(dados['internet'])
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# 0            Yes              No
# 1             No             Yes
# 2             No              No
# 3            Yes             Yes
# 4            Yes              No
# ...          ...             ...
# 7262          No              No
# 7263          No             Yes
# 7264          No              No
# 7265          No             Yes
# 7266         Yes             Yes
#
# [7267 rows x 7 columns]

# %%
pd.json_normalize(dados['account'])
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year              Yes      Mailed check            65.60
# 1     Month-to-month               No      Mailed check            59.90
# 2     Month-to-month              Yes  Electronic check            73.90
# 3     Month-to-month              Yes  Electronic check            98.00
# 4     Month-to-month              Yes      Mailed check            83.90
# ...              ...              ...               ...              ...
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 0            593.3
# 1            542.4
# 2           280.85
# 3          1237.85
# 4            267.4
# ...            ...
# 7262         742.9
# 7263        1873.7
# 7264         92.75
# 7265       4627.65
# 7266        3707.6
#
# [7267 rows x 5 columns]

# %% [markdown]
# Agora que temos uma melhor ideia da estrutura de nossos dados usaremos as livrarias request e json para ler os dados em formato json e transformaremos esses dados em um diccionario.

# %%
import requests
import json

dados_json = requests.get(url)
dados_dict = json.loads(dados_json.text)
pd.DataFrame(dados_dict)
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 0        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1       {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                                 ...
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 0     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4     {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...                                                 ...
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account
# 0     {'Contract': 'One year', 'PaperlessBilling': '...
# 1     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4     {'Contract': 'Month-to-month', 'PaperlessBilli...
# ...                                                 ...
# 7262  {'Contract': 'One year', 'PaperlessBilling': '...
# 7263  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7264  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7265  {'Contract': 'Two year', 'PaperlessBilling': '...
# 7266  {'Contract': 'Two year', 'PaperlessBilling': '...
#
# [7267 rows x 6 columns]

# %% [markdown]
# Agora normalizaremos o diccionario com os dados usando a função json_normalize()

# %%
dados_normalizados  = pd.json_normalize(dados_dict,sep='_')
dados_normalizados
# Out:
#       customerID Churn customer_gender  customer_SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer_Partner customer_Dependents  customer_tenure phone_PhoneService  \
# 0                 Yes                 Yes                9                Yes
# 1                  No                  No                9                Yes
# 2                  No                  No                4                Yes
# 3                 Yes                  No               13                Yes
# 4                 Yes                  No                3                Yes
# ...               ...                 ...              ...                ...
# 7262               No                  No               13                Yes
# 7263              Yes                  No               22                Yes
# 7264               No                  No                2                Yes
# 7265              Yes                 Yes               67                Yes
# 7266              Yes                 Yes               63                 No
#
#      phone_MultipleLines internet_InternetService  ... internet_OnlineBackup  \
# 0                     No                      DSL  ...                   Yes
# 1                    Yes                      DSL  ...                    No
# 2                     No              Fiber optic  ...                    No
# 3                     No              Fiber optic  ...                   Yes
# 4                     No              Fiber optic  ...                    No
# ...                  ...                      ...  ...                   ...
# 7262                  No                      DSL  ...                    No
# 7263                 Yes              Fiber optic  ...                    No
# 7264                  No                      DSL  ...                   Yes
# 7265                  No                      DSL  ...                    No
# 7266    No phone service                      DSL  ...                   Yes
#
#      internet_DeviceProtection internet_TechSupport internet_StreamingTV  \
# 0                           No                  Yes                  Yes
# 1                           No                   No                   No
# 2                          Yes                   No                   No
# 3                          Yes                   No                  Yes
# 4                           No                  Yes                  Yes
# ...                        ...                  ...                  ...
# 7262                        No                  Yes                   No
# 7263                        No                   No                   No
# 7264                        No                   No                   No
# 7265                       Yes                  Yes                   No
# 7266                       Yes                   No                  Yes
#
#      internet_StreamingMovies account_Contract account_PaperlessBilling  \
# 0                          No         One year                      Yes
# 1                         Yes   Month-to-month                       No
# 2                          No   Month-to-month                      Yes
# 3                         Yes   Month-to-month                      Yes
# 4                          No   Month-to-month                      Yes
# ...                       ...              ...                      ...
# 7262                       No         One year                       No
# 7263                      Yes   Month-to-month                      Yes
# 7264                       No   Month-to-month                      Yes
# 7265                      Yes         Two year                       No
# 7266                      Yes         Two year                       No
#
#      account_PaymentMethod account_Charges_Monthly  account_Charges_Total
# 0             Mailed check                   65.60                  593.3
# 1             Mailed check                   59.90                  542.4
# 2         Electronic check                   73.90                 280.85
# 3         Electronic check                   98.00                1237.85
# 4             Mailed check                   83.90                  267.4
# ...                    ...                     ...                    ...
# 7262          Mailed check                   55.15                  742.9
# 7263      Electronic check                   85.10                 1873.7
# 7264          Mailed check                   50.30                  92.75
# 7265          Mailed check                   67.85                4627.65
# 7266      Electronic check                   59.00                 3707.6
#
# [7267 rows x 21 columns]

# %% [markdown]
# #🔧 Transformação

# %% [markdown]
# Agora que conseguimos extrair os dados podemos comezar a revisar a presença de dados nulos e se os campos estão no formato certo.

# %%
dados_normalizados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer_gender            7267 non-null   object
#  3   customer_SeniorCitizen     7267 non-null   int64
#  4   customer_Partner           7267 non-null   object
#  5   customer_Dependents        7267 non-null   object
#  6   customer_tenure            7267 non-null   int64
#  7   phone_PhoneService         7267 non-null   object
#  8   phone_MultipleLines        7267 non-null   object
#  9   internet_InternetService   7267 non-null   object
#  10  internet_OnlineSecurity    7267 non-null   object
#  11  internet_OnlineBackup      7267 non-null   object
#  12  internet_DeviceProtection  7267 non-null   object
#  13  internet_TechSupport       7267 non-null   object
#  14  internet_StreamingTV       7267 non-null   object
#  15  internet_StreamingMovies   7267 non-null   object
#  16  account_Contract           7267 non-null   object
#  17  account_PaperlessBilling   7267 non-null   object
#  18  account_PaymentMethod      7267 non-null   object
#  19  account_Charges_Monthly    7267 non-null   float64
#  20  account_Charges_Total      7267 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.2+ MB

# %% [markdown]
# - Não temos valores nulos nos dados.

# %% [markdown]
# ## Verificando inconsistencias
#
# Verificaremos agora os tipos de dados das colunas, como customerID não será usada na analise omitiremos ela da revisão. A seguir uma lista com a descrição dos dados.
# - Churn: se o cliente deixou ou não a empresa
# - gender: gênero (masculino e feminino)
# - SeniorCitizen: informação sobre um cliente ter ou não idade igual ou maior que - 65 anos
# - Partner: se o cliente possui ou não um parceiro ou parceira
# - Dependents: se o cliente possui ou não dependentes
# - tenure: meses de contrato do cliente
# - PhoneService: assinatura de serviço telefônico
# - MultipleLines: assisnatura de mais de uma linha de telefone
# - InternetService: assinatura de um provedor internet
# - OnlineSecurity: assinatura adicional de segurança online
# - OnlineBackup: assinatura adicional de backup online
# - DeviceProtection: assinatura adicional de proteção no dispositivo
# - TechSupport: assinatura adicional de suporte técnico, menos tempo de espera
# - StreamingTV: assinatura de TV a cabo
# - StreamingMovies: assinatura de streaming de filmes
# - Contract: tipo de contrato
# - PaperlessBilling: se o cliente prefere receber online a fatura
# - PaymentMethod: forma de pagamento
# - Charges.Monthly: total de todos os serviços do cliente por mês
# - Charges.Total: total gasto pelo cliente

# %% [markdown]
# ### Churn
# Começaremos pela variável resposta **Churn**

# %%
dados_normalizados['Churn'].value_counts(dropna=False)
# Out:
# Churn
# No     5174
# Yes    1869
#         224
# Name: count, dtype: int64

# %%
print(f"Temos {len([i for i in dados_normalizados['Churn'] if i not in ['Yes','No']])} valores diferentes de Yes e No, dado que esse campo será usado como variável resposta precisaremos remover esses registros.")
# Out:
# Temos 224 valores diferentes de Yes e No, dado que esse campo será usado como variável resposta precisaremos remover esses registros.

# %%
dados_tratados = dados_normalizados[dados_normalizados['Churn'].isin(['Yes','No'])].copy()
dados_tratados['Churn'] = dados_tratados['Churn'].map({'Yes':True,'No':False})

# %% [markdown]
# Antes de revisar as demás variáveis podemos agrupar elas pelo tipo de variável que esperamos de acordo com a descrição e revisando rapidamente os valores que elas adotam. Para isso podemos usar a função unique().

# %%
for i in dados_tratados.columns[2:]:
  print(f'\n{i}')
  print(f'Valores únicos: {dados_tratados[i].unique()}')
# Out:
# customer_gender
# Valores únicos: ['Female' 'Male']
#
# customer_SeniorCitizen
# Valores únicos: [0 1]
#
# customer_Partner
# Valores únicos: ['Yes' 'No']
#
# customer_Dependents
# Valores únicos: ['Yes' 'No']
#
# customer_tenure
# Valores únicos: [ 9  4 13  3 71 63  7 65 54 72  5 56 34  1 45 50 23 55 26 69 37 49 66 67
#  20 43 59 12 27  2 25 29 14 35 64 39 40 11  6 30 70 57 58 16 32 33 10 21
#  61 15 44 22 24 19 47 62 46 52  8 60 48 28 41 53 68 31 36 17 18 51 38 42
#   0]
#
# phone_PhoneService
# Valores únicos: ['Yes' 'No']
#
# phone_MultipleLines
# Valores únicos: ['No' 'Yes' 'No phone service']
#
# internet_InternetService
# Valores únicos: ['DSL' 'Fiber optic' 'No']
#
# internet_OnlineSecurity
# Valores únicos: ['No' 'Yes' 'No internet service']
#
# internet_OnlineBackup
# Valores únicos: ['Yes' 'No' 'No internet service']
#
# internet_DeviceProtection
# Valores únicos: ['No' 'Yes' 'No internet service']
#
# internet_TechSupport
# Valores únicos: ['Yes' 'No' 'No internet service']
#
# internet_StreamingTV
# Valores únicos: ['Yes' 'No' 'No internet service']
#
# internet_StreamingMovies
# Valores únicos: ['No' 'Yes' 'No internet service']
#
# account_Contract
# Valores únicos: ['One year' 'Month-to-month' 'Two year']
#
# account_PaperlessBilling
# Valores únicos: ['Yes' 'No']
#
# account_PaymentMethod
# Valores únicos: ['Mailed check' 'Electronic check' 'Credit card (automatic)'
#  'Bank transfer (automatic)']
#
# account_Charges_Monthly
# Valores únicos: [65.6  59.9  73.9  ... 91.75 68.8  67.85]
#
# account_Charges_Total
# Valores únicos: ['593.3' '542.4' '280.85' ... '742.9' '4627.65' '3707.6']

# %%
variaveis_booleanas = [
    'customer_gender'
    ,'customer_SeniorCitizen'
    ,'customer_Partner'
    ,'customer_Dependents'
    ,'phone_PhoneService'
    ,'account_PaperlessBilling'
]
variaveis_categoricas = [
    'phone_MultipleLines'
    ,'internet_InternetService'
    ,'internet_OnlineSecurity'
    ,'internet_OnlineBackup'
    ,'internet_DeviceProtection'
    ,'internet_TechSupport'
    ,'internet_StreamingTV'
    ,'internet_StreamingMovies'
    ,'account_Contract'
    ,'account_PaymentMethod'
]
variaveis_int = [
    'customer_tenure'
]
variaveis_float = [
    'account_Charges_Monthly'
    ,'account_Charges_Total'
]

# %%
# verificando que consideramos todas as variáveis
if [v for v in dados_tratados.columns[2:] if v not in variaveis_booleanas+variaveis_categoricas+variaveis_int+variaveis_float] == []:
  print('Todas as variáveis foram consideradas')
# verificando que não temos interseções entre grupos de variáveis
if len(set(variaveis_booleanas+variaveis_categoricas+variaveis_int+variaveis_float)) == len(variaveis_booleanas+variaveis_categoricas+variaveis_int+variaveis_float):
  print('Sem interseções')
# Out:
# Todas as variáveis foram consideradas
# Sem interseções

# %% [markdown]
# Agora revisamos se existem valores inconsistentes nas variávies por tipo de variável.

# %% [markdown]
# ### Variáveis booleanas:

# %%
for i in variaveis_booleanas:
  print(f'\n')
  print(dados_tratados[i].value_counts(dropna=False))
# Out:
# customer_gender
# Male      3555
# Female    3488
# Name: count, dtype: int64
#
#
# customer_SeniorCitizen
# 0    5901
# 1    1142
# Name: count, dtype: int64
#
#
# customer_Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64
#
#
# customer_Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64
#
#
# phone_PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64
#
#
# account_PaperlessBilling
# Yes    4171
# No     2872
# Name: count, dtype: int64

# %% [markdown]
# Não temos valores inconsistentes nas variáveis booleanas, todas tem apenas 2 categorias. No entanto para treinar modelos eles apenas aceitarám valores numéricos ou booleanos, por tanto transformaremos os valores para o tipo bool. No caso da variável customer_gender criaremos uma variável equivalente que nomearemos customer_is_male.

# %%
dados_tratados['customer_SeniorCitizen'] = dados_tratados['customer_SeniorCitizen'].map({0:False,1:True})
dados_tratados['customer_Partner'] = dados_tratados['customer_Partner'].map({'No':False,'Yes':True})
dados_tratados['customer_Dependents'] = dados_tratados['customer_Dependents'].map({'No':False,'Yes':True})
dados_tratados['phone_PhoneService'] = dados_tratados['phone_PhoneService'].map({'No':False,'Yes':True})
dados_tratados['account_PaperlessBilling'] = dados_tratados['account_PaperlessBilling'].map({'No':False,'Yes':True})
dados_tratados['customer_is_male'] = dados_tratados['customer_gender'].map({'Female':False,'Male':True})
dados_tratados.drop(columns='customer_gender',inplace=True) # removendo variavel costumer_gender

# Atualizamos a lista de variáveis booleanas
variaveis_booleanas.remove('customer_gender')
variaveis_booleanas.append('customer_is_male')

# %%
# Verificando tipos de dados bool
dados_tratados[variaveis_booleanas].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_SeniorCitizen    7043 non-null   bool
#  1   customer_Partner          7043 non-null   bool
#  2   customer_Dependents       7043 non-null   bool
#  3   phone_PhoneService        7043 non-null   bool
#  4   account_PaperlessBilling  7043 non-null   bool
#  5   customer_is_male          7043 non-null   bool
# dtypes: bool(6)
# memory usage: 96.3 KB

# %% [markdown]
# ### Variaveis int e float

# %%
dados_tratados[variaveis_int+variaveis_float].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 0 to 7266
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customer_tenure          7043 non-null   int64
#  1   account_Charges_Monthly  7043 non-null   float64
#  2   account_Charges_Total    7043 non-null   object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 220.1+ KB

# %% [markdown]
# Precisaremos trocar o tipo de dados apenas da variável account_Charges_Total

# %%
try:
  dados_tratados['account_Charges_Total'] = dados_tratados['account_Charges_Total'].astype(float)
except Exception as e:
  print(f"Ocorreu um erro tipo {type(e)}: {e}")
# Out:
# Ocorreu um erro tipo <class 'ValueError'>: could not convert string to float: ' '

# %% [markdown]
# Isso significa que temos valores em branco no campo account_Charges_Total. Mas pode ser um espaço em branco adicional ao número ou que o dado tenha apenas o espaço em branco. Precisamos identificar quais os elementos únicos que estáo gerando o erro.

# %%
valores_com_espaco = [v for v in dados_tratados['account_Charges_Total'] if ' ' in v]
print(f'Quantidade de valores com espaço em branco: {len(valores_com_espaco)} ({len(valores_com_espaco)/dados_tratados.shape[0]*100:.2f}%)')
print(f'Valores unicos com espaço em branco: {set(valores_com_espaco)}')
# Out:
# Quantidade de valores com espaço em branco: 11 (0.16%)
# Valores unicos com espaço em branco: {' '}

# %%
dados_tratados[dados_tratados['account_Charges_Total'] == ' ']
# Out:
#       customerID  Churn  customer_SeniorCitizen  customer_Partner  \
# 975   1371-DWPAZ  False                   False              True
# 1775  2520-SGTTA  False                   False              True
# 1955  2775-SEFEE  False                   False             False
# 2075  2923-ARZLG  False                   False              True
# 2232  3115-CZMZD  False                   False             False
# 2308  3213-VVOLG  False                   False              True
# 2930  4075-WKNIU  False                   False              True
# 3134  4367-NUYAO  False                   False              True
# 3203  4472-LVYGI  False                   False              True
# 4169  5709-LVOEQ  False                   False              True
# 5599  7644-OMVMY  False                   False              True
#
#       customer_Dependents  customer_tenure  phone_PhoneService  \
# 975                  True                0               False
# 1775                 True                0                True
# 1955                 True                0                True
# 2075                 True                0                True
# 2232                 True                0                True
# 2308                 True                0                True
# 2930                 True                0                True
# 3134                 True                0                True
# 3203                 True                0               False
# 4169                 True                0                True
# 5599                 True                0                True
#
#      phone_MultipleLines internet_InternetService internet_OnlineSecurity  \
# 975     No phone service                      DSL                     Yes
# 1775                  No                       No     No internet service
# 1955                 Yes                      DSL                     Yes
# 2075                  No                       No     No internet service
# 2232                  No                       No     No internet service
# 2308                 Yes                       No     No internet service
# 2930                 Yes                      DSL                      No
# 3134                 Yes                       No     No internet service
# 3203    No phone service                      DSL                     Yes
# 4169                  No                      DSL                     Yes
# 5599                  No                       No     No internet service
#
#       ... internet_DeviceProtection internet_TechSupport internet_StreamingTV  \
# 975   ...                       Yes                  Yes                  Yes
# 1775  ...       No internet service  No internet service  No internet service
# 1955  ...                        No                  Yes                   No
# 2075  ...       No internet service  No internet service  No internet service
# 2232  ...       No internet service  No internet service  No internet service
# 2308  ...       No internet service  No internet service  No internet service
# 2930  ...                       Yes                  Yes                  Yes
# 3134  ...       No internet service  No internet service  No internet service
# 3203  ...                       Yes                  Yes                  Yes
# 4169  ...                       Yes                   No                  Yes
# 5599  ...       No internet service  No internet service  No internet service
#
#      internet_StreamingMovies account_Contract account_PaperlessBilling  \
# 975                        No         Two year                    False
# 1775      No internet service         Two year                    False
# 1955                       No         Two year                     True
# 2075      No internet service         One year                     True
# 2232      No internet service         Two year                    False
# 2308      No internet service         Two year                    False
# 2930                       No         Two year                    False
# 3134      No internet service         Two year                    False
# 3203                       No         Two year                     True
# 4169                      Yes         Two year                    False
# 5599      No internet service         Two year                    False
#
#           account_PaymentMethod account_Charges_Monthly  \
# 975     Credit card (automatic)                   56.05
# 1775               Mailed check                   20.00
# 1955  Bank transfer (automatic)                   61.90
# 2075               Mailed check                   19.70
# 2232               Mailed check                   20.25
# 2308               Mailed check                   25.35
# 2930               Mailed check                   73.35
# 3134               Mailed check                   25.75
# 3203  Bank transfer (automatic)                   52.55
# 4169               Mailed check                   80.85
# 5599               Mailed check                   19.85
#
#       account_Charges_Total customer_is_male
# 975                                    False
# 1775                                   False
# 1955                                    True
# 2075                                    True
# 2232                                    True
# 2308                                    True
# 2930                                   False
# 3134                                    True
# 3203                                   False
# 4169                                   False
# 5599                                    True
#
# [11 rows x 21 columns]

# %% [markdown]
# Por outra parte podemos ver que todos os registros onde account_Charges_Total = ' ' correspondem apenas à categoria Churn = False. Considerando isso e o baixo numero de registros excluiremos esses casos e transformaremos a variavel para float.

# %%
dados_tratados = dados_tratados[dados_tratados['account_Charges_Total'] != ' ']
dados_tratados['account_Charges_Total'] = dados_tratados['account_Charges_Total'].astype(float)

# %%
dados_tratados[variaveis_int+variaveis_float].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7266
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customer_tenure          7032 non-null   int64
#  1   account_Charges_Monthly  7032 non-null   float64
#  2   account_Charges_Total    7032 non-null   float64
# dtypes: float64(2), int64(1)
# memory usage: 219.8 KB

# %% [markdown]
# Agora revisaremos se os dados apresentam valores inconsistentes nas variáveis numéricas (int + float).

# %%
dados_tratados[variaveis_int+variaveis_float].describe()
# Out:
#        customer_tenure  account_Charges_Monthly  account_Charges_Total
# count      7032.000000              7032.000000            7032.000000
# mean         32.421786                64.798208            2283.300441
# std          24.545260                30.085974            2266.771362
# min           1.000000                18.250000              18.800000
# 25%           9.000000                35.587500             401.450000
# 50%          29.000000                70.350000            1397.475000
# 75%          55.000000                89.862500            3794.737500
# max          72.000000               118.750000            8684.800000

# %% [markdown]
# Os valores aparentam ser razoáveis com relação a descrição das variáveis.

# %% [markdown]
# ### Variáveis Categóricas
#
# Revisaremos a quantidade de registros em cada categoria das variáveis.

# %%
for i in variaveis_categoricas:
  print(f'\n')
  print(dados_tratados[i].value_counts(dropna=False))
# Out:
# phone_MultipleLines
# No                  3385
# Yes                 2967
# No phone service     680
# Name: count, dtype: int64
#
#
# internet_InternetService
# Fiber optic    3096
# DSL            2416
# No             1520
# Name: count, dtype: int64
#
#
# internet_OnlineSecurity
# No                     3497
# Yes                    2015
# No internet service    1520
# Name: count, dtype: int64
#
#
# internet_OnlineBackup
# No                     3087
# Yes                    2425
# No internet service    1520
# Name: count, dtype: int64
#
#
# internet_DeviceProtection
# No                     3094
# Yes                    2418
# No internet service    1520
# Name: count, dtype: int64
#
#
# internet_TechSupport
# No                     3472
# Yes                    2040
# No internet service    1520
# Name: count, dtype: int64
#
#
# internet_StreamingTV
# No                     2809
# Yes                    2703
# No internet service    1520
# Name: count, dtype: int64
#
#
# internet_StreamingMovies
# No                     2781
# Yes                    2731
# No internet service    1520
# Name: count, dtype: int64
#
#
# account_Contract
# Month-to-month    3875
# Two year          1685
# One year          1472
# Name: count, dtype: int64
#
#
# account_PaymentMethod
# Electronic check             2365
# Mailed check                 1604
# Bank transfer (automatic)    1542
# Credit card (automatic)      1521
# Name: count, dtype: int64

# %% [markdown]
# Não observamos categorias inconsistentes com a descrição das variáveis. No entanto podemos traduzir as categorias para o Português, assim tornar os dados mais acessíveis.

# %%
variaveis_categoricas
# Out:
# ['phone_MultipleLines',
#  'internet_InternetService',
#  'internet_OnlineSecurity',
#  'internet_OnlineBackup',
#  'internet_DeviceProtection',
#  'internet_TechSupport',
#  'internet_StreamingTV',
#  'internet_StreamingMovies',
#  'account_Contract',
#  'account_PaymentMethod']

# %%
dados_tratados['phone_MultipleLines'] = dados_tratados['phone_MultipleLines'].map({'No phone service':'Sem serviço','No':'Não','Yes':'Sim'})
dados_tratados['internet_InternetService'] = dados_tratados['internet_InternetService'].map({'Fiber optic':'Fibra Ótica','No':'Não','DSL':'DSL'})
dados_tratados['internet_OnlineSecurity'] = dados_tratados['internet_OnlineSecurity'].map({'No internet service':'Sem serviço','No':'Não','Yes':'Sim'})
dados_tratados['internet_OnlineBackup'] = dados_tratados['internet_OnlineBackup'].map({'No internet service':'Sem serviço','No':'Não','Yes':'Sim'})
dados_tratados['internet_DeviceProtection'] = dados_tratados['internet_DeviceProtection'].map({'No internet service':'Sem serviço','No':'Não','Yes':'Sim'})
dados_tratados['internet_TechSupport'] = dados_tratados['internet_TechSupport'].map({'No internet service':'Sem serviço','No':'Não','Yes':'Sim'})
dados_tratados['internet_StreamingTV'] = dados_tratados['internet_StreamingTV'].map({'No internet service':'Sem serviço','No':'Não','Yes':'Sim'})
dados_tratados['internet_StreamingMovies'] = dados_tratados['internet_StreamingMovies'].map({'No internet service':'Sem serviço','No':'Não','Yes':'Sim'})
dados_tratados['account_Contract'] = dados_tratados['account_Contract'].map({'Month-to-month':'Mensal','One year':'Anual','Two year':'Dois anos'})
dados_tratados['account_PaymentMethod'] = dados_tratados['account_PaymentMethod'].map({
    'Electronic check':'Cheque eletrônico'
    ,'Mailed check':'Cheque'
    ,'Bank transfer (automatic)':'Transferência bancária'
    ,'Credit card (automatic)':'Cartão de crédito'
})

# %%
for i in variaveis_categoricas:
  print(f'\n')
  print(dados_tratados[i].value_counts(dropna=False))
# Out:
# phone_MultipleLines
# Não            3385
# Sim            2967
# Sem serviço     680
# Name: count, dtype: int64
#
#
# internet_InternetService
# Fibra Ótica    3096
# DSL            2416
# Não            1520
# Name: count, dtype: int64
#
#
# internet_OnlineSecurity
# Não            3497
# Sim            2015
# Sem serviço    1520
# Name: count, dtype: int64
#
#
# internet_OnlineBackup
# Não            3087
# Sim            2425
# Sem serviço    1520
# Name: count, dtype: int64
#
#
# internet_DeviceProtection
# Não            3094
# Sim            2418
# Sem serviço    1520
# Name: count, dtype: int64
#
#
# internet_TechSupport
# Não            3472
# Sim            2040
# Sem serviço    1520
# Name: count, dtype: int64
#
#
# internet_StreamingTV
# Não            2809
# Sim            2703
# Sem serviço    1520
# Name: count, dtype: int64
#
#
# internet_StreamingMovies
# Não            2781
# Sim            2731
# Sem serviço    1520
# Name: count, dtype: int64
#
#
# account_Contract
# Mensal       3875
# Dois anos    1685
# Anual        1472
# Name: count, dtype: int64
#
#
# account_PaymentMethod
# Cheque eletrônico         2365
# Cheque                    1604
# Transferência bancária    1542
# Cartão de crédito         1521
# Name: count, dtype: int64

# %% [markdown]
# Agora que revisamos as inconsistencias e tratamos os dados podemos resetar o index e renomear as colunas para tornar a informação mais clara e acessível.

# %%
dados_tratados.reset_index(drop=True,inplace=True)

# %%
tradutor_variaveis = {
    'customerID':'cliente_id'
    ,'Churn':'churn'
    ,'customer_SeniorCitizen':'cliente_idoso'
    ,'customer_Partner':'cliente_tem_parceiro'
    ,'customer_Dependents':'cliente_tem_dependentes'
    ,'customer_tenure':'meses_contrato'
    ,'phone_PhoneService':'servico_telefonico'
    ,'phone_MultipleLines':'multiplas_linhas'
    ,'internet_InternetService':'assinatura_internet'
    ,'internet_OnlineSecurity':'seguranca_online'
    ,'internet_OnlineBackup':'backup_online'
    ,'internet_DeviceProtection':'protecao_dispositivo'
    ,'internet_TechSupport':'suporte_tecnico'
    ,'internet_StreamingTV':'tv_a_cabo'
    ,'internet_StreamingMovies':'streaming_filmes'
    ,'account_Contract':'contrato'
    ,'account_PaperlessBilling':'fatura_online'
    ,'account_PaymentMethod':'forma_pagamento'
    ,'account_Charges_Monthly':'faturamento_mensal'
    ,'account_Charges_Total':'faturamento_total'
    ,'customer_is_male':'cliente_masculino'
}
dados_tratados.rename(columns=tradutor_variaveis,inplace=True)

# %%
dados_tratados.head()
# Out:
#    cliente_id  churn  cliente_idoso  cliente_tem_parceiro  \
# 0  0002-ORFBO  False          False                  True
# 1  0003-MKNFE  False          False                 False
# 2  0004-TLHLJ   True          False                 False
# 3  0011-IGKFF   True           True                  True
# 4  0013-EXCHZ   True           True                  True
#
#    cliente_tem_dependentes  meses_contrato  servico_telefonico  \
# 0                     True               9                True
# 1                    False               9                True
# 2                    False               4                True
# 3                    False              13                True
# 4                    False               3                True
#
#   multiplas_linhas assinatura_internet seguranca_online  ...  \
# 0              Não                 DSL              Não  ...
# 1              Sim                 DSL              Não  ...
# 2              Não         Fibra Ótica              Não  ...
# 3              Não         Fibra Ótica              Não  ...
# 4              Não         Fibra Ótica              Não  ...
#
#   protecao_dispositivo suporte_tecnico tv_a_cabo streaming_filmes contrato  \
# 0                  Não             Sim       Sim              Não    Anual
# 1                  Não             Não       Não              Sim   Mensal
# 2                  Sim             Não       Não              Não   Mensal
# 3                  Sim             Não       Sim              Sim   Mensal
# 4                  Não             Sim       Sim              Não   Mensal
#
#   fatura_online    forma_pagamento faturamento_mensal  faturamento_total  \
# 0          True             Cheque               65.6             593.30
# 1         False             Cheque               59.9             542.40
# 2          True  Cheque eletrônico               73.9             280.85
# 3          True  Cheque eletrônico               98.0            1237.85
# 4          True             Cheque               83.9             267.40
#
#    cliente_masculino
# 0              False
# 1               True
# 2               True
# 3               True
# 4              False
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Adicionando coluna de contas diarias
#
# Usamos o faturamento mensal para calcular o valor diário, proporcionando uma visão mais detalhada do comportamento dos clientes ao longo do tempo.

# %%
dados_tratados['contas_diarias'] = dados_tratados['faturamento_mensal']/30

# %%
dados_tratados.head()
# Out:
#    cliente_id  churn  cliente_idoso  cliente_tem_parceiro  \
# 0  0002-ORFBO  False          False                  True
# 1  0003-MKNFE  False          False                 False
# 2  0004-TLHLJ   True          False                 False
# 3  0011-IGKFF   True           True                  True
# 4  0013-EXCHZ   True           True                  True
#
#    cliente_tem_dependentes  meses_contrato  servico_telefonico  \
# 0                     True               9                True
# 1                    False               9                True
# 2                    False               4                True
# 3                    False              13                True
# 4                    False               3                True
#
#   multiplas_linhas assinatura_internet seguranca_online  ... suporte_tecnico  \
# 0              Não                 DSL              Não  ...             Sim
# 1              Sim                 DSL              Não  ...             Não
# 2              Não         Fibra Ótica              Não  ...             Não
# 3              Não         Fibra Ótica              Não  ...             Não
# 4              Não         Fibra Ótica              Não  ...             Sim
#
#   tv_a_cabo streaming_filmes contrato fatura_online    forma_pagamento  \
# 0       Sim              Não    Anual          True             Cheque
# 1       Não              Sim   Mensal         False             Cheque
# 2       Não              Não   Mensal          True  Cheque eletrônico
# 3       Sim              Sim   Mensal          True  Cheque eletrônico
# 4       Sim              Não   Mensal          True             Cheque
#
#    faturamento_mensal faturamento_total  cliente_masculino  contas_diarias
# 0                65.6            593.30              False        2.186667
# 1                59.9            542.40               True        1.996667
# 2                73.9            280.85               True        2.463333
# 3                98.0           1237.85               True        3.266667
# 4                83.9            267.40              False        2.796667
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Salvando Dados Tratados

# %%
dados_tratados.to_csv('dados_tratados.csv',index=False)

# %% [markdown]
# #📊 Carga e análise

# %% [markdown]
# ## Teste de Leitura dos dados

# %%
# Testando a carga dos dados
import pandas as pd
try:
  df = pd.read_csv('/content/dados_tratados.csv')
except:
  # Se não rodam as celulas anteriores é possivel pegar dos dados tratados do repositorio
  df = pd.read_csv('https://raw.githubusercontent.com/Angel-Arroyo-H/alura-data-science-challenge-2/refs/heads/main/dados_tratados.csv')

df
# Out:
#       cliente_id  churn  cliente_idoso  cliente_tem_parceiro  \
# 0     0002-ORFBO  False          False                  True
# 1     0003-MKNFE  False          False                 False
# 2     0004-TLHLJ   True          False                 False
# 3     0011-IGKFF   True           True                  True
# 4     0013-EXCHZ   True           True                  True
# ...          ...    ...            ...                   ...
# 7027  9987-LUTYD  False          False                 False
# 7028  9992-RRAMN   True          False                  True
# 7029  9992-UJOEL  False          False                 False
# 7030  9993-LHIEB  False          False                  True
# 7031  9995-HOTOH  False          False                  True
#
#       cliente_tem_dependentes  meses_contrato  servico_telefonico  \
# 0                        True               9                True
# 1                       False               9                True
# 2                       False               4                True
# 3                       False              13                True
# 4                       False               3                True
# ...                       ...             ...                 ...
# 7027                    False              13                True
# 7028                    False              22                True
# 7029                    False               2                True
# 7030                     True              67                True
# 7031                     True              63               False
#
#      multiplas_linhas assinatura_internet seguranca_online  ...  \
# 0                 Não                 DSL              Não  ...
# 1                 Sim                 DSL              Não  ...
# 2                 Não         Fibra Ótica              Não  ...
# 3                 Não         Fibra Ótica              Não  ...
# 4                 Não         Fibra Ótica              Não  ...
# ...               ...                 ...              ...  ...
# 7027              Não                 DSL              Sim  ...
# 7028              Sim         Fibra Ótica              Não  ...
# 7029              Não                 DSL              Não  ...
# 7030              Não                 DSL              Sim  ...
# 7031      Sem serviço                 DSL              Sim  ...
#
#      suporte_tecnico tv_a_cabo streaming_filmes   contrato fatura_online  \
# 0                Sim       Sim              Não      Anual          True
# 1                Não       Não              Sim     Mensal         False
# 2                Não       Não              Não     Mensal          True
# 3                Não       Sim              Sim     Mensal          True
# 4                Sim       Sim              Não     Mensal          True
# ...              ...       ...              ...        ...           ...
# 7027             Sim       Não              Não      Anual         False
# 7028             Não       Não              Sim     Mensal          True
# 7029             Não       Não              Não     Mensal          True
# 7030             Sim       Não              Sim  Dois anos         False
# 7031             Não       Sim              Sim  Dois anos         False
#
#         forma_pagamento  faturamento_mensal faturamento_total  \
# 0                Cheque               65.60            593.30
# 1                Cheque               59.90            542.40
# 2     Cheque eletrônico               73.90            280.85
# 3     Cheque eletrônico               98.00           1237.85
# 4                Cheque               83.90            267.40
# ...                 ...                 ...               ...
# 7027             Cheque               55.15            742.90
# 7028  Cheque eletrônico               85.10           1873.70
# 7029             Cheque               50.30             92.75
# 7030             Cheque               67.85           4627.65
# 7031  Cheque eletrônico               59.00           3707.60
#
#       cliente_masculino  contas_diarias
# 0                 False        2.186667
# 1                  True        1.996667
# 2                  True        2.463333
# 3                  True        3.266667
# 4                 False        2.796667
# ...                 ...             ...
# 7027              False        1.838333
# 7028               True        2.836667
# 7029               True        1.676667
# 7030               True        2.261667
# 7031               True        1.966667
#
# [7032 rows x 22 columns]

# %% [markdown]
# ## Analise Descritiva

# %% [markdown]
# ### Distribuição do Churn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

proporcao_churn = df['churn'].value_counts(normalize=True)
def churn():
  # Calcular a proporção de usuários que deram churn
  proporcao_churn = df['churn'].value_counts(normalize=True)

  # Configurações do gráfico de rosca
  fig, ax = plt.subplots(figsize=(8, 6), facecolor='white')
  ax.set_facecolor(sns.color_palette("rocket")[5])

  # Plotar o gráfico de rosca
  cores = [sns.color_palette("rocket")[1], sns.color_palette("rocket")[4]]
  wedges, texts, autotexts = ax.pie(
      proporcao_churn
      ,labels=proporcao_churn.index.map({True:'Cancelaram',False:'Permanecem'})
      ,autopct='%1.1f%%'
      ,startangle=180
      ,wedgeprops=dict(width=0.4, edgecolor=None)
      ,pctdistance=0.8
      ,colors=cores
  )

  # Adicionar rótulos e título
  plt.title('Churn dos Clientes ', fontsize=18)

  # Configurar rótulos e porcentagens com as cores especificadas
  for text, autotext, color in zip(texts, autotexts, cores):
      text.set_color(color)
      text.set_fontsize(12)
      autotext.set_color('white')
      autotext.set_fontsize(12)

  return plt

churn();

# %% [markdown]
# ### Contagem de Churn por Variáveis Categóricas

# %%
vars_categoricas = df.dtypes[df.dtypes == 'object'].index[1:].tolist()
vars_categoricas
# Out:
# ['multiplas_linhas',
#  'assinatura_internet',
#  'seguranca_online',
#  'backup_online',
#  'protecao_dispositivo',
#  'suporte_tecnico',
#  'tv_a_cabo',
#  'streaming_filmes',
#  'contrato',
#  'forma_pagamento']

# %%
df.multiplas_linhas.value_counts()
# Out:
# multiplas_linhas
# Não            3385
# Sim            2967
# Sem serviço     680
# Name: count, dtype: int64

# %%
import plotly.express as px

def churn_por_categoria(variavel_categorica:str):
  with sns.color_palette("rocket"):
    # bar plot
    fig, ax = plt.subplots(figsize=(8, 4))
    ax = px.histogram(df, x=variavel_categorica, text_auto=True, color='churn',barmode='group',width=600,height=400)

#    categorias = [c.capitalize() for c in percentagem_avaliacao_loja.columns]
#    valores_acumulados = [0] * len(categorias)
#
#    for avaliacao in percentagem_avaliacao_loja.index:
#        valores = percentagem_avaliacao_loja.loc[avaliacao].values
#        bars = ax.barh(categorias, valores, left=valores_acumulados, label=avaliacao)
#        # Add valores in the middle of each bar
#        for bar, valor, valor_acumulado in zip(bars, valores, valores_acumulados):
#            ax.text(
#                valor_acumulado + valor / 2,                # Middle of the bar
#                bar.get_y() + 0.4,  # Center of the bar
#                f'{valor*100:.1f}%',                        # Value to display
#                ha='center', va='center', color='white', fontsize=10
#            )
#        valores_acumulados = [b + v for b, v in zip(valores_acumulados, valores)]
#
#    # Customizando o gráfico
#    ax.set_ylabel('')
#    ax.set_xlabel('')
#    ax.set_title('Distribuição das Avaliações\n', fontsize=16,loc='left')
#    ax.yaxis.set_tick_params(labelsize=12)
#
#    # Retirando caixa em volta e eixo y
#    ax.set_frame_on(False)
#    ax.axes.get_xaxis().set_visible(False)
#    ax.tick_params(axis='both',which='both',length=0)
#
#    # Capitalizando legendas
#    handles, labels = ax.get_legend_handles_labels()
#    capitalized_labels = [label.capitalize() for label in labels]
#    plt.legend(handles, capitalized_labels, title="Avaliação",loc='upper left', bbox_to_anchor=(1, 1))

    return plt

churn_por_categoria('multiplas_linhas');
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py'>

# %%
px.histogram(
    df
    ,x='multiplas_linhas'
    ,text_auto=True
    ,color='churn'
    ,barmode='group'
    ,width=600
    ,height=400
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="be029995-e2dc-4151-a18d-07ed08bc3bc6" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be029995-e2dc-4151-a18d-07ed08bc3bc6")) {                    Plotly.newPlot(                        "be029995-e2dc-4151-a18d-07ed08bc3bc6",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"churn=False\u003cbr\u003emultiplas_linhas=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"False","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"False","offsetgroup":"False","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Não","Sim","Não","Não","Sim","Não","Sim","Sem serviço","Sim","Não","Sim","Sem serviço","Sim","Sem serviço","Sim","Sim","Sim","Não","Não","Não","Não","Não","Não","Não","Sim","Não","Sem serviço","Sim","Sim","Sim","Não","Sim","Não","Sim","Não","Sem serviço","Sim","Não","Não","Não","Não","Sim","Sim","Não","Sim","Sim","Não","Sim","Sim","Não","Sim","Sim","Não","Sim","Sem serviço","Sim","Não","Não","Sem serviço","Sim","Sem serviço","Não","Não","Sim","Não","Sim","Não","Sim","Não","Sim","Sim","Não","Sim","Sim","Sim","Não","Sim","Não","Sim","Não","Não","Não","Sem serviço","Não","Sim","Sim","Sim","Não","Sim","Não","Sem serviço","Sem serviço","Não","Sim","Não","Não","Não","Sem serviço","Não","Não","Não","Sim","Sim","Sem serviço","Sem serviço","Sim","Sem serviço","Sim","Sim","Sim","Sim","Não","Sim","Não","Sim","Não","Sim","Não","Sim","Não","Sim","Não","Não","Sim","Sim","Sim","Sim","Sem serviço","Não","Sem serviço","Não","Sem serviço","Não","Não","Sim","Não","Não","Sem serviço","Sem serviço","Não","Sim","Não","Sem serviço","Não","Sim","Sem serviço","Não","Não","Não","Não","Não","Não","Não","Não","Sim","Sim","Sim","Sim","Sim","Sem serviço","Não","Sem serviço","Sim","Não","Não","Não","Sim","Não","Sem serviço","Não","Sim","Sim","Não","Sim","Não","Não","Sem serviço","Não","Não","Não","Não","Não","Sim","Não","Não","Não","Sim","Sem serviço","Não","Não","Sim","Sim","Não","Não","Sim","Não","Sim","Sim","Não","Sim","Não","Sim","Não","Não","Sim","Sim","Não","Sim","Não","Não","Não","Sim","Não","Sim","Sim","Não","Não","Sim","Sim","Não","Não","Sim","Sim","Não","Sim","Não","Sem serviço","Sim","Sim","Não","Não","Não","Não","Sim","Não","Não","Sim","Sim","Não","Sim","Sim","Não","Não","Sim","Não","Não","Sim","Não","Não","Não","Não","Não","Sim","Sim","Não","Não","Sim","Não","Sem serviço","Sem serviço","Sim","Sim","Sim","Sim","Sim","Não","Não","Sim","Não","Não","Sim","Não","Não","Não","Não","Sim","Sim","Sem serviço","Sim","Sim","Não","Sem serviço","Não","Sim","Não","Sim","Sim","Não","Sim","Não","Sim","Não","Não","Sim","Não","Não","Não","Sim","Não","Sim","Não","Não","Sim","Não","Não","Não","Sim","Sem serviço","Não","Sim","Não","Não","Sim","Sim","Não","Não","Não","Não","Não","Não","Sim","Sim","Não","Não","Sim","Não","Sim","Sem serviço","Sim","Não","Não","Sim","Não","Sim","Sim","Sim","Não","Não","Não","Não","Sim","Não","Sem serviço","Sim","Não","Não","Sim","Sim","Sim","Sim","Não","Sim","Sem serviço","Sim","Sim","Sim","Sim","Não","Sim","Não","Sem serviço","Sim","Não","Sem serviço","Sim","Sim","Sem serviço","Não","Não","Não","Sem serviço","Sim","Sem serviço","Sim","Sim","Sim","Sem serviço","Não","Sim","Não","Sim","Não","Não","Sim","Não","Sim","Sim","Sim","Não","Sem serviço","Sim","Sim","Sim","Sem serviço","Sim","Não","Não","Não","Sim","Sim","Sim","Não","Não","Não","Não","Não","Não","Sim","Sim","Não","Não","Sim","Não","Não","Sem serviço","Não","Não","Não","Sim","Não","Não","Não","Sim","Sim","Não","Não","Não","Não","Sim","Sim","Sim","Sim","Não","Não","Não","Sem serviço","Sim","Sim","Sim","Não","Não","Sim","Sim","Sem serviço","Sim","Sim","Sim","Sim","Sim","Sim","Não","Sem s ...

# %% [markdown]
# #📄Relatorio Final
